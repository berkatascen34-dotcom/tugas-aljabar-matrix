# %%
import numpy as np

# Misalkan nilai s (contoh: s = 1)
s = 1

# Buat vector (kolom)
v = np.array([[2*s],
              [2],
              [-3],
              [-2*s]])

print("Vector awal:")
print(v)

# Transpose vector
v_T = v.T

print("\nTranspose vector:")
print(v_T)
# Out:
# Vector awal:
# [[ 2]
#  [ 2]
#  [-3]
#  [-2]]
#
# Transpose vector:
# [[ 2  2 -3 -2]]

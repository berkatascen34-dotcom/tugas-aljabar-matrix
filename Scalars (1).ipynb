# %%
x = 82

# %%
type(x) # if we'd like more specificity (e.g., int16, uint8), we need NumPy or another numeric library
# Out:
# int

# %%
y = 35

# %%
type(y) # if we'd like more specificity (e.g., int16, uint8), we need NumPy or another numeric library
# Out:
# int

# %%
py_sum = x + y
py_sum
# Out:
# 117

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.82

# %%
float_sum = x_float + y
float_sum
# Out:
# 35.82

# %%
type(float_sum)
# Out:
# float

# %%
import tensorflow as tfv

# %%
x_tf = tf.Variable(25, dtype=tf.int16) # dtype is optional
x_tf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1312/3873114052.py in <cell line: 0>()
# ----> 1 x_tf = tf.Variable(25, dtype=tf.int16) # dtype is optional
#       2 x_tf
#
# NameError: name 'tf' is not defined

# %%
import torch

# %%
x_pt = torch.tensor(82) # type specification optional, e.g.: dtype=torch.float16
x_pt
# Out:
# tensor(82)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %%
import torch

# Membuat tensor 4 dimensi
images_pt = torch.zeros((32, 28, 28, 3))

print("Bentuk tensor:", images_pt.shape)
# Out:
# Bentuk tensor: torch.Size([32, 28, 28, 3])

# %%
# Notasi umum (Generic Tensor)
# (N, H, W, C)

N = 32  # jumlah data (batch size)
H = 28  # tinggi gambar (height)
W = 28  # lebar gambar (width)
C = 3   # jumlah channel (RGB)

# %%
# Ambil 1 gambar pertama
gambar_1 = images_pt[0]

print("Shape 1 gambar:", gambar_1.shape)
# Out:
# Shape 1 gambar: torch.Size([28, 28, 3])

# %%
# Ambil pixel di baris 0, kolom 0 dari gambar pertama
pixel = images_pt[0, 0, 0]

print("Nilai pixel:", pixel)
# Out:
# Nilai pixel: tensor([0., 0., 0.])
